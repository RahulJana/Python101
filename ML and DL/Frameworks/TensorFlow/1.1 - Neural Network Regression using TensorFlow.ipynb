# %% [markdown]
# # 📖 Topics to be covered:
# 1. Architecture of a neural network regression model.
# 2. Input shapes and Output shapes of a regresion model(Features and Labels)
# 3. Creation of custom data to view and fit
# 4. Steps in modeling
#     * Creating a model
#     * Compiling a model
#     * Fitting a model
#     * Evaluating a model
# 5. Different Evaluation Methodes
# 6. Saving, Loading and Reusing Models
#
#     🏠***The Housing Price Prediction***

# %%
import tensorflow as tf

# %% [markdown]
# ### Architecture of a NN:

# %% [markdown]
# ![Screenshot from 2021-04-01 13-41-44.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2021-04-01 21-45-39.png](data:image/png;base64,...)

# %% [markdown]
# The cmd for markDOwn cell or the text cell is ctrl+m+m

# %% [markdown]
# ### Inputs and Outputs of a NN:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating Input for our Neural Network

# %%
# Create Features
X = np.array([-07.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create Labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize
plt.plot(X,y), plt.scatter(X,y, color = "r")
plt.xlabel("X---->")
plt.ylabel("y---->")
# Out:
# Text(0, 0.5, 'y---->')

# %%
plt.plot(X, (X+10)) # The simple relation ship

# %%
y == (X+10)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# ### Input and Output Shape

# %%
# Creating a Demo tensor for the input of our model; TO KNOW THE SHAPE OF OUR TENSOR
house_info = tf.constant(["Bedroom", "Bathroom", "Garage"])
house_price = tf.constant([939700])

house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'Bedroom', b'Bathroom', b'Garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %% [markdown]
# As we can see that Input shape is `(3,)` and Output shape is `(1,)`

# %% [markdown]
# ## Steps in modeling:
# 1. ***Creating a model:*** Define the input and the output layer, as well as the hidden layers of a deep learning model
# 2. ***Compiling a model:*** Defining the Loss Function, the Optimizer and the Evaluation Matrix.
# 3. ***Fitting the model:*** Letting the model try to find pattern between X and y.

# %%
import keras

# %% [markdown]
# SHIFT + CTRL + SPACE ----->  Bring out the Doc String

# %%
# Model Building


# Set the random seed for "Reproducibility"
tf.random.set_seed(69)


# 1. Creating the model using sequential api
model = keras.Sequential([
                          keras.layers.Dense(1) # We can pass/create a architecture of a Neural Network; as elements of list or using model.add()
                        ])

# 2. Compile the model
model.compile(loss = keras.losses.mae, # MAE is a loss function; MAE --> Mean Absolute Error
              optimizer = keras.optimizers.SGD(), # SGD --> Stochastic Gradient Descent
              metrics = ["mae"] # Evaluation matrix
              )

# 3. Fit the Model
model.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 305ms/step - loss: 13.1032 - mae: 13.1032
# Epoch 2/10
# 1/1 [==============================] - 0s 6ms/step - loss: 12.9707 - mae: 12.9707
# Epoch 3/10
# 1/1 [==============================] - 0s 6ms/step - loss: 12.8382 - mae: 12.8382
# Epoch 4/10
# 1/1 [==============================] - 0s 7ms/step - loss: 12.7057 - mae: 12.7057
# Epoch 5/10
# 1/1 [==============================] - 0s 7ms/step - loss: 12.5732 - mae: 12.5732
# Epoch 6/10
# 1/1 [==============================] - 0s 5ms/step - loss: 12.4407 - mae: 12.4407
# Epoch 7/10
# 1/1 [==============================] - 0s 8ms/step - loss: 12.3082 - mae: 12.3082
# Epoch 8/10
# 1/1 [==============================] - 0s 5ms/step - loss: 12.1757 - mae: 12.1757
# Epoch 9/10
# 1/1 [==============================] - 0s 12ms/step - loss: 12.0432 - mae: 12.0432
# Epoch 10/10
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9107 - mae: 11.9107

# %%
y_pred = model.predict(
    [17.0] # For 17 the output value should be 27;
)
y_pred # Since the value of y_pred is very off..... as the mae is very high.
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78b18e6dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[7.9770794]], dtype=float32)

# %%
y_pred + 12 # As we can see that the even-if we add the mae with the y_pred; still y_pred is very off; that suggests that our model is bad.
# Out:
# array([[19.97708]], dtype=float32)

# %% [markdown]
# ### Another way of creating the model: `model.add()`

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Dense(1))
model2.compile(loss = keras.losses.mae, optimizer = keras.optimizers.SGD(), metrics= ["mae"])
model2.fit(X, y, epochs = 10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 303ms/step - loss: 21.8498 - mae: 21.8498
# Epoch 2/10
# 1/1 [==============================] - 0s 6ms/step - loss: 21.4566 - mae: 21.4566
# Epoch 3/10
# 1/1 [==============================] - 0s 8ms/step - loss: 21.0635 - mae: 21.0635
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 20.6704 - mae: 20.6704
# Epoch 5/10
# 1/1 [==============================] - 0s 8ms/step - loss: 20.3263 - mae: 20.3263
# Epoch 6/10
# 1/1 [==============================] - 0s 6ms/step - loss: 20.0451 - mae: 20.0451
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 19.7638 - mae: 19.7638
# Epoch 8/10
# 1/1 [==============================] - 0s 6ms/step - loss: 19.4826 - mae: 19.4826
# Epoch 9/10
# 1/1 [==============================] - 0s 7ms/step - loss: 19.2013 - mae: 19.2013
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 18.9201 - mae: 18.9201

# %% [markdown]
# ![Screenshot from 2021-04-03 00-01-01.png](data:image/png;base64,...)

# %% [markdown]
# ### Improving the NN model:
# We create a model in  three steps.
#
# 1. **Creating a Model:** We can add more layer, So it becomes **more deep**, We can **incerease the number of Hidden Unit** ; We can even **add activation function**.
#
# 2. **Compiling a model:** We can change optimization function, we can change **Learning rate** of the optimization function.
#
# 3. **Fitting model:** We can add **more epochs**, or we canm feed **more Data** to the model.

# %% [markdown]
# #### Increase the model's epochs

# %%
# Create a model
model = keras.Sequential([keras.layers.Dense(1)])

# Compile a Model
model.compile(loss= keras.losses.mae, optimizer=keras.optimizers.SGD(), metrics= ["mae"])

# Fitting a model larger epoches (Accuracy/evaluation matrix will overshoot)
model.fit(X, y, epochs= 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 319ms/step - loss: 14.3472 - mae: 14.3472
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 14.2147 - mae: 14.2147
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 14.0822 - mae: 14.0822
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.9497 - mae: 13.9497
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.8172 - mae: 13.8172
# Epoch 6/100
# 1/1 [==============================] - 0s 10ms/step - loss: 13.6847 - mae: 13.6847
# Epoch 7/100
# 1/1 [==============================] - 0s 10ms/step - loss: 13.5522 - mae: 13.5522
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.4197 - mae: 13.4197
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.2872 - mae: 13.2872
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 13.1547 - mae: 13.1547
# Epoch 11/100
# ...

# %% [markdown]
# `Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.9225 - mae: 6.9225
# <tensorflow.python.keras.callbacks.History at 0x7fe02ce0e1d0>`
# Although its better .... Not better enough

# %%
# New Premdictions
y_pred = model.predict([17.0])
y_pred # Close
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78b1813dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[29.497713]], dtype=float32)

# %%
# Improved model:
model_3 = keras.Sequential([
                           keras.layers.Dense(100, activation = "relu"),
                           keras.layers.Dense(100, activation = "relu"),
                           keras.layers.Dense(1), # Output layer and its a regression model; and we are calculating a number. So one unit in the output layer
                            ])

model_3.compile(
               loss = keras.losses.mae,
               optimizer = keras.optimizers.Adam(learning_rate=0.001),
               metrics= ["mae"]
               )

model_3.fit(X, y, epochs = 100) # Since Amount of data is limited; So IN THIS CASE model won't perform well.
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 454ms/step - loss: 12.4460 - mae: 12.4460
# Epoch 2/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.0662 - mae: 12.0662
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.6925 - mae: 11.6925
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.3264 - mae: 11.3264
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.9603 - mae: 10.9603
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.6006 - mae: 10.6006
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 10.2473 - mae: 10.2473
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.8990 - mae: 9.8990
# Epoch 9/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.5863 - mae: 9.5863
# Epoch 10/100
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2982 - mae: 9.2982
# Epoch 11/100
# ...

# %% [markdown]
# `Epoch 100/100
# 1/1 [==============================] - 0s 15ms/step - loss: 3.3840 - mae: 3.3840
# <tensorflow.python.keras.callbacks.History at 0x7f92262e8510>`
#
# ***As we can see in this case model is performing better than others, But not good enough as we don't have enough `Data` .***

# %%
model_3.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 100)               200
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 101
# ...
# Total params: 10,401
# Trainable params: 10,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Architecture of the model
from keras.utils import plot_model

plot_model(model_3)

# %%
X, y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 14.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 24.]))

# %%
# Lets see the Improved Prediction
y_pred = model_3.predict([17.0, 32.0])
y_pred # its good but a bit off. for 2nd one way off
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78b15d6cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[31.635656],
#        [58.089558]], dtype=float32)

# %% [markdown]
# ### Evaluating a model
#
# Model Building Workflow:
# `Build a model --> ( Fit it --> Eavuate it --> Tweak it --> Fit it --> ) --> Untill Satisfied Result is recieved`
#
# > ***In Model Evaluation Visualization is key component***
#
#
# Good Way of Visualization:
# 1. Visualize the Data ***(Both Input and Output)***
# 2. Visualize the Model ***How is the model look-like***
# 3. Visualize the Performance of the model ***How good it is learning***
# 4. Visualize the Evaluation ***How Good is the prediction***

# %%
# Making a bigger Dataset
X = tf.range(-300, 300, 4)
X
# Out:
# <tf.Tensor: shape=(150,), dtype=int32, numpy=
# array([-300, -296, -292, -288, -284, -280, -276, -272, -268, -264, -260,
#        -256, -252, -248, -244, -240, -236, -232, -228, -224, -220, -216,
#        -212, -208, -204, -200, -196, -192, -188, -184, -180, -176, -172,
#        -168, -164, -160, -156, -152, -148, -144, -140, -136, -132, -128,
#        -124, -120, -116, -112, -108, -104, -100,  -96,  -92,  -88,  -84,
#         -80,  -76,  -72,  -68,  -64,  -60,  -56,  -52,  -48,  -44,  -40,
#         -36,  -32,  -28,  -24,  -20,  -16,  -12,   -8,   -4,    0,    4,
#           8,   12,   16,   20,   24,   28,   32,   36,   40,   44,   48,
#          52,   56,   60,   64,   68,   72,   76,   80,   84,   88,   92,
#          96,  100,  104,  108,  112,  116,  120,  124,  128,  132,  136,
#         140,  144,  148,  152,  156,  160,  164,  168,  172,  176,  180,
#         184,  188,  192,  196,  200,  204,  208,  212,  216,  220,  224,
# ...

# %%
# Make label for the dataset
y = X + 7
y
# Out:
# <tf.Tensor: shape=(150,), dtype=int32, numpy=
# array([-293, -289, -285, -281, -277, -273, -269, -265, -261, -257, -253,
#        -249, -245, -241, -237, -233, -229, -225, -221, -217, -213, -209,
#        -205, -201, -197, -193, -189, -185, -181, -177, -173, -169, -165,
#        -161, -157, -153, -149, -145, -141, -137, -133, -129, -125, -121,
#        -117, -113, -109, -105, -101,  -97,  -93,  -89,  -85,  -81,  -77,
#         -73,  -69,  -65,  -61,  -57,  -53,  -49,  -45,  -41,  -37,  -33,
#         -29,  -25,  -21,  -17,  -13,   -9,   -5,   -1,    3,    7,   11,
#          15,   19,   23,   27,   31,   35,   39,   43,   47,   51,   55,
#          59,   63,   67,   71,   75,   79,   83,   87,   91,   95,   99,
#         103,  107,  111,  115,  119,  123,  127,  131,  135,  139,  143,
#         147,  151,  155,  159,  163,  167,  171,  175,  179,  183,  187,
#         191,  195,  199,  203,  207,  211,  215,  219,  223,  227,  231,
# ...

# %%
plt.figure(figsize = (12,9))
plt.scatter(X,y), plt.plot(X,y, color = "red")
# Out:
# (<matplotlib.collections.PathCollection at 0x7f78b15dc3d0>,
#  [<matplotlib.lines.Line2D at 0x7f78b15dc150>])

# %% [markdown]
# ### Three Set concept
#
# 1. **Training Set:** The model learns from this set(70% - 80% of our total data.)
# 2. **Validation set:** The Validation(The tewaking part) will done here.(10% - 15% of total data.)
# 3. **Test Set:** The Testing will be done here(10% - 15% of total Data.)

# %% [markdown]
# ![Screenshot from 2021-04-04 15-51-28.png](data:image/png;base64,...)

# %%
# Size of total training sample - 150
150*.15
# Out:
# 22.5

# %%
# Spliting the dataset into Training and Testing

# Training Set
X_train = X[:130]
y_train = y[:130]

# Testing Set
X_test = X[130:]
y_test = y[130:]

# Printing the size
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (130, 130, 20, 20)

# %% [markdown]
# ### 👀 Visualize the Data

# %%
# Plot Size
plt.figure(figsize = (16,9))

# Visualizing the training data
plt.scatter(X_train, y_train, c = "b", label = "Training Data")

# Visiualizing the testing data
plt.scatter(X_test, y_test, c = "r", label = "Testing Data")

# Showing the legends
plt.legend()

# %% [markdown]
# ### Model Building

# %%
# 1. Creating a model
model = keras.Sequential([
                          keras.layers.Dense(1) # keras.layers.Dense(1) <----- We are using one hidden unit as for a single value "X" ; will be used to calculate the respective value of y 
])

# 2. Model compilation
model.compile(loss = "mae",
              optimizer = keras.optimizers.SGD(learning_rate= 0.001 ),
              metrics = ["mae"])

# 3. Fitting a model
model.fit(X_train, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 4ms/step - loss: 299.2816 - mae: 299.2816
# Epoch 2/10
# 5/5 [==============================] - 0s 3ms/step - loss: 206.4088 - mae: 206.4088
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 118.1272 - mae: 118.1272
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 30.6557 - mae: 30.6557
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 7.6991 - mae: 7.6991
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 6.6907 - mae: 6.6907
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 7.5297 - mae: 7.5297
# Epoch 8/10
# 5/5 [==============================] - 0s 4ms/step - loss: 7.3113 - mae: 7.3113
# Epoch 9/10
# 5/5 [==============================] - 0s 4ms/step - loss: 7.7371 - mae: 7.7371
# Epoch 10/10
# 5/5 [==============================] - 0s 4ms/step - loss: 8.7393 - mae: 8.7393

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 🔬 A small Troubleshooting......

# %%
"""
# 1. Creating a model
model_9 = keras.Sequential([
                          keras.layers.Dense(1) # keras.layers.Dense(1) <----- We are using one hidden unit as for a single value "X" ; will be used to calculate the respective value of y 
])

# 2. Model compilation
model_9.compile(loss = "mae",
              optimizer = keras.optimizers.SGD(learning_rate= 0.001 ),
              metrics = ["mae"])

# Let's see how the model will look
# model_9.summary()   # <--------------------------------------------------------------------------------- THE CAUSE OF PROBLEM ❌❌❌❌❌❌❌❌❌❌
'''
    ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data,
        or specify an `input_shape` argument in the first layer(s) for automatic build.


We can't access the model summary without running it, or without passing the input shape.
'''

# 3. Fitting a model
# model.fit(X_train, y_train, epochs = 10)
"""
# Out:
# '\n# 1. Creating a model\nmodel_9 = keras.Sequential([\n                          keras.layers.Dense(1) # keras.layers.Dense(1) <----- We are using one hidden unit as for a single value "X" ; will be used to calculate the respective value of y \n])\n\n# 2. Model compilation\nmodel_9.compile(loss = "mae",\n              optimizer = keras.optimizers.SGD(learning_rate= 0.001 ),\n              metrics = ["mae"])\n\n# Let\'s see how the model will look\n# model_9.summary()   # <--------------------------------------------------------------------------------- THE CAUSE OF PROBLEM ❌❌❌❌❌❌❌❌❌❌\n\'\'\'\n    ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data,\n        or specify an `input_shape` argument in the first layer(s) for automatic build.\n\n\nWe can\'t access the model summary without running it, or without passing the input shape.\n\'\'\'\n\n# 3. Fitting a model\n# model.fit(X_train, y_train, epochs = 10)\n'

# %% [markdown]
# ##### We will build a model wthat has a input shape. So that it can get built automatically

# %%
# Difining the Random Seed
tf.random.set_seed(69)

# %%
# Shape of X_train
X_train.shape
# Out:
# TensorShape([130])

# %%
# Shape of the 1st element
X_train[0].shape
# Out:
# TensorShape([])

# %% [markdown]
# THis is a **Scaler Value.**

# %%
print(X_train[0])
print(y_train[0])
# Out:
# tf.Tensor(-300, shape=(), dtype=int32)
# tf.Tensor(-293, shape=(), dtype=int32)

# %% [markdown]
# *Both X_train and y_train is a single number;* Our `input_sahpe = 1`

# %%
# Create a model ....... Just like the above
model_new = keras.Sequential([
                              keras.layers.Dense(10, input_shape = [1], name = "LOL") # We can define the name of the layer.
], name = "Chota_model") # Model name can't contain < space > !!!!!!

# Compiling the model
model_new.compile(loss = "mae",
                  optimizer = keras.optimizers.SGD(),
                  metrics = ["mae"])

# Model Summary
model_new.summary() # Now we can add model Summary
# Out:
# Model: "Chota_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# LOL (Dense)                  (None, 10)                20
# ...
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# _________________________________________________________________
# LOL (Dense)                  (None, 1)                 2
# __________________________________________________________________
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
#
#
#
# > * **Total Parameters:-** Total numbers of parameters that model can learn.
# > * ***Trainable Parameters:-*** These are tha parameters; that model can update as the model is being trained.
# > * ***Non-trainable Parameters:-*** These parameters are not updated during the training --- (When we use pretrained model in ***Transfer Learning***)
#
#
# * In our model all the parameters are trainable.
# * When we use pretrained models in our training; then we freze the already learned parameters..... Which results in `Total Parameters != Trainable Parameters` and There we will **use/face** the `Non-Trainable Parameters`.

# %%
# Fitting the model
print(model_new.fit(X_train, y_train, epochs= 10, verbose = 0))

# %%
model_new.fit(X_train, y_train, epochs= 10, verbose = 1) # verbose = 1 <----- By Default; When it is one It shows the progress bar
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 8.5883 - mae: 8.5883
# Epoch 2/10
# 5/5 [==============================] - 0s 4ms/step - loss: 9.0880 - mae: 9.0880
# Epoch 3/10
# 5/5 [==============================] - 0s 4ms/step - loss: 8.4491 - mae: 8.4491
# Epoch 4/10
# 5/5 [==============================] - 0s 4ms/step - loss: 10.0713 - mae: 10.0713
# Epoch 5/10
# 5/5 [==============================] - 0s 4ms/step - loss: 7.0847 - mae: 7.0847
# Epoch 6/10
# 5/5 [==============================] - 0s 4ms/step - loss: 7.8012 - mae: 7.8012
# Epoch 7/10
# 5/5 [==============================] - 0s 4ms/step - loss: 7.8595 - mae: 7.8595
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 8.0150 - mae: 8.0150
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 10.2760 - mae: 10.2760
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 9.1572 - mae: 9.1572

# %%
model_new.summary()
# Out:
# Model: "Chota_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# LOL (Dense)                  (None, 10)                20
# ...
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 💠 Ploting the model 🔥🔥🔥🔥

# %%
from keras.utils import plot_model

# %%
plot_model(model_new) # Plot the architecture of the model

# %%
# Lets tweak it
plot_model(model_new, show_shapes= True)

# %%
# Lets try this on model_3
plot_model(model_3, show_shapes= True, show_dtype= True, show_layer_names = True, to_file = "model_3.png") # show_layer_names = True ; ------> Bydefault

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ### 👀 Visualizing the model Predictions
#
# To visialize predictions; it is good to plot them against groud truth labels.
#
#
# Often we will encounter (`y_test` or `y_true`) vs `y_pred`
# >>> ***Ground Truth  vs Predictions***

# %%
# Making predictions
y_pred = model.predict(X_test)
y_pred
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f78b208a3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[223.93852],
#        [228.00975],
#        [232.08098],
#        [236.1522 ],
#        [240.22342],
#        [244.29465],
#        [248.36588],
#        [252.4371 ],
#        [256.50833],
#        [260.57956],
#        [264.6508 ],
# ...

# %%
y_test
# Out:
# <tf.Tensor: shape=(20,), dtype=int32, numpy=
# array([227, 231, 235, 239, 243, 247, 251, 255, 259, 263, 267, 271, 275,
#        279, 283, 287, 291, 295, 299, 303], dtype=int32)>

# %%
plt.plot(y_pred, color = "blue"), plt.plot(y_test, color = "red")
# Out:
# ([<matplotlib.lines.Line2D at 0x7f78b209d1d0>],
#  [<matplotlib.lines.Line2D at 0x7f78b2006c90>])

# %% [markdown]
# ### 💠 With a ploting function

# %%
# Lets a create a ploting function
def plot_prediction(train_data = X_train, train_labels = y_train, test_data = X_test, test_labels = y_test, predictions = y_pred):
    """ train_data = X_train, train_labels = y_train, test_data = X_test, test_labels = y_test, predictions = y_pred;
    > > > This functions plots the training data and compares it with the ground truth labels. """
    
    # Size of the plot
    plt.figure(figsize = (16, 9))

    # Ploting the training data @(Blue color)
    plt.scatter(train_data, train_labels, color = "blue", label = "Training Data -->")

    # Plotting the testing data @(red Color)
    plt.scatter(test_data, test_labels, color = "green", label = "Testing Data -->")

    #ploting the model Predictions
    plt.scatter(test_data, predictions, color = "red", label = "Predictions" )

    # Showing the legends
    plt.legend();

# %%
plot_prediction()

# %%
plot_prediction?

# %% [markdown]
# ### 💠 Evaluating our model with regression evaluation matrix:
#
# Depending on the model the evaluation matrix could be anything.....
# We are working on a ***Regression Problem***. thus --->
# * ***MAE:*** Mean Absolute Error. "On average, how wrong is each of my model's predictions"
# * ***MSE:*** Mean Squared Error. "Square the Average Error."

# %% [markdown]
# ![Screenshot from 2021-04-08 18-27-58.png](data:image/png;base64,...)

# %%
print(y_test)
# Out:
# tf.Tensor(
# [227 231 235 239 243 247 251 255 259 263 267 271 275 279 283 287 291 295
#  299 303], shape=(20,), dtype=int32)

# %%
print(y_pred)
# Out:
# [[223.93852]
#  [228.00975]
#  [232.08098]
#  [236.1522 ]
#  [240.22342]
#  [244.29465]
#  [248.36588]
#  [252.4371 ]
#  [256.50833]
#  [260.57956]
#  [264.6508 ]
#  [268.72202]
#  [272.79324]
#  [276.86447]
#  [280.9357 ]
#  [285.00693]
#  [289.07816]
#  [293.14938]
#  [297.2206 ]
#  [301.29184]]

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 105ms/step - loss: 2.3848 - mae: 2.3848
# [2.3848235607147217, 2.3848235607147217]

# %% [markdown]
# `[loss: 2.3848 ; mae: 2.3848]`
# Here We are having evaluation matric as mae as we have set it in `model.compile()`
# loss ---> 2.3848235607147217
#
# Evaluation matrix ---> 2.3848235607147217

# %% [markdown]
# ### `tf.keras.losses.MAE()` vs `tf.keras.losses.MSE()`

# %%
mae_model = tf.losses.MAE(y_test, y_pred)
mse_model = tf.losses.MSE(y_test, y_pred)

mae_model, mse_model
# Out:
# (<tf.Tensor: shape=(20,), dtype=float32, numpy=
#  array([41.061478, 37.091225, 33.535217, 30.393457, 27.665949, 25.352676,
#         23.45365 , 21.968868, 20.898335, 20.242044, 20.      , 20.172201,
#         20.758648, 21.759342, 23.17428 , 25.003464, 27.246893, 29.904568,
#         32.97649 , 36.462654], dtype=float32)>,
#  <tf.Tensor: shape=(20,), dtype=float32, numpy=
#  array([2218.045  , 1900.2786 , 1615.6621 , 1364.1952 , 1145.8789 ,
#          960.71173,  808.6941 ,  689.82635,  604.10846,  551.5403 ,
#          532.12195,  545.8534 ,  592.7346 ,  672.7656 ,  785.94653,
#          932.27716, 1111.7576 , 1324.388  , 1570.168  , 1849.0977 ],
#        dtype=float32)>)

# %%
mae_model = tf.losses.mae(y_test, y_pred)
mse_model = tf.losses.mse(y_test, y_pred)

mae_model, mse_model
# Out:
# (<tf.Tensor: shape=(20,), dtype=float32, numpy=
#  array([41.061478, 37.091225, 33.535217, 30.393457, 27.665949, 25.352676,
#         23.45365 , 21.968868, 20.898335, 20.242044, 20.      , 20.172201,
#         20.758648, 21.759342, 23.17428 , 25.003464, 27.246893, 29.904568,
#         32.97649 , 36.462654], dtype=float32)>,
#  <tf.Tensor: shape=(20,), dtype=float32, numpy=
#  array([2218.045  , 1900.2786 , 1615.6621 , 1364.1952 , 1145.8789 ,
#          960.71173,  808.6941 ,  689.82635,  604.10846,  551.5403 ,
#          532.12195,  545.8534 ,  592.7346 ,  672.7656 ,  785.94653,
#          932.27716, 1111.7576 , 1324.388  , 1570.168  , 1849.0977 ],
#        dtype=float32)>)

# %% [markdown]
# As we can see that `tf.keras.losses.mae() == tf.keras.losses.MAE()`

# %% [markdown]
# ### `tf.keras.metrics.mean_absolute_error()` vs `tf.keras.metrics.mean_squared_error()`

# %%
eval_model_mae = tf.keras.metrics.mean_absolute_error(y_true = y_test, y_pred = y_pred)
eval_model_mae
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([41.061478, 37.091225, 33.535217, 30.393457, 27.665949, 25.352676,
#        23.45365 , 21.968868, 20.898335, 20.242044, 20.      , 20.172201,
#        20.758648, 21.759342, 23.17428 , 25.003464, 27.246893, 29.904568,
#        32.97649 , 36.462654], dtype=float32)>

# %%
evaluation_mae2 = tf.keras.metrics.mae(y_test, y_pred)
evaluation_mae2
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([41.061478, 37.091225, 33.535217, 30.393457, 27.665949, 25.352676,
#        23.45365 , 21.968868, 20.898335, 20.242044, 20.      , 20.172201,
#        20.758648, 21.759342, 23.17428 , 25.003464, 27.246893, 29.904568,
#        32.97649 , 36.462654], dtype=float32)>

# %%
eval_model_mse = tf.keras.metrics.mean_squared_error(y_true= y_test, y_pred = y_pred)
eval_model_mse
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([2218.045  , 1900.2786 , 1615.6621 , 1364.1952 , 1145.8789 ,
#         960.71173,  808.6941 ,  689.82635,  604.10846,  551.5403 ,
#         532.12195,  545.8534 ,  592.7346 ,  672.7656 ,  785.94653,
#         932.27716, 1111.7576 , 1324.388  , 1570.168  , 1849.0977 ],
#       dtype=float32)>

# %%
evaluation_mse2 = tf.keras.metrics.mse(y_test, y_pred)
evaluation_mse2
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([2218.045  , 1900.2786 , 1615.6621 , 1364.1952 , 1145.8789 ,
#         960.71173,  808.6941 ,  689.82635,  604.10846,  551.5403 ,
#         532.12195,  545.8534 ,  592.7346 ,  672.7656 ,  785.94653,
#         932.27716, 1111.7576 , 1324.388  , 1570.168  , 1849.0977 ],
#       dtype=float32)>

# %%
y_pred # It is a multi dim array
# Out:
# array([[223.93852],
#        [228.00975],
#        [232.08098],
#        [236.1522 ],
#        [240.22342],
#        [244.29465],
#        [248.36588],
#        [252.4371 ],
#        [256.50833],
#        [260.57956],
#        [264.6508 ],
#        [268.72202],
#        [272.79324],
#        [276.86447],
#        [280.9357 ],
#        [285.00693],
#        [289.07816],
#        [293.14938],
#        [297.2206 ],
#        [301.29184]], dtype=float32)

# %%
tf.constant(y_pred) # Now it is a tensor
# Out:
# <tf.Tensor: shape=(20, 1), dtype=float32, numpy=
# array([[223.93852],
#        [228.00975],
#        [232.08098],
#        [236.1522 ],
#        [240.22342],
#        [244.29465],
#        [248.36588],
#        [252.4371 ],
#        [256.50833],
#        [260.57956],
#        [264.6508 ],
#        [268.72202],
#        [272.79324],
#        [276.86447],
#        [280.9357 ],
#        [285.00693],
#        [289.07816],
#        [293.14938],
#        [297.2206 ],
#        [301.29184]], dtype=float32)>

# %%
tf.squeeze(y_pred) # vector
# Out:
# <tf.Tensor: shape=(20,), dtype=float32, numpy=
# array([223.93852, 228.00975, 232.08098, 236.1522 , 240.22342, 244.29465,
#        248.36588, 252.4371 , 256.50833, 260.57956, 264.6508 , 268.72202,
#        272.79324, 276.86447, 280.9357 , 285.00693, 289.07816, 293.14938,
#        297.2206 , 301.29184], dtype=float32)>

# %%
evaluation_model_new_mae = tf.keras.metrics.mae(y_true= y_test, y_pred = tf.squeeze(tf.constant(y_pred)))
evaluation_model_new_mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.3848236>

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 2.3848 - mae: 2.3848
# [2.3848235607147217, 2.3848235607147217]

# %% [markdown]
# ***As we can see that the value of mae() evaluation and `tf.keras.metrics.mae()` is same>***

# %%
# Mean Squared Error
# if in the model.compile(); evaluation matric was mse()
evaluation_model_mse = tf.keras.metrics.mse(y_true= y_test, y_pred = tf.squeeze(tf.constant(y_pred)))
evaluation_model_mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.856072>

# %% [markdown]
# Error will be higher as in `mse()` we are taking the square of error.

# %%
# Lets try Hubber loss; as this is less suceptive towards outliers.
huber_loss_model = tf.keras.losses.huber(X_test, y_test)
huber_loss_model
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.5>

# %%
huber_loss_model_2 = tf.keras.losses.Huber()
huber_loss_model_2(X_test, y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=6.5>

# %% [markdown]
# ### 💠 Custom made functions to reuse `MAE()` and `MSE()`

# %%
# the helper function for mae()
def metric_mae(y_true, y_pred):
    return tf.keras.metrics.mae(y_true = y_true, y_pred = y_pred)

# %%
# The helper function for mse()
def metrics_mse(y_true, y_pred):
    return tf.keras.metrics.mse(y_true = y_true, y_pred = y_pred)

# %% [markdown]
# ### 💠 Comparing the model using pandas

# %%
import pandas as pd

# %%
model_result = pd.DataFrame([["model_1", evaluation_model_new_mae.numpy(), evaluation_model_mse.numpy(), huber_loss_model.numpy()]])
print(model_result)
# Out:
#          0         1         2    3
# 0  model_1  2.384824  5.856072  6.5

# %%
model_result.plot(kind = "bar")

# %%
all_result = pd.DataFrame(model_result, columns = ["model_name", "MAE", "MSE", "Huber"])

all_result
# Out:
#    model_name  MAE  MSE  Huber
# 0         NaN  NaN  NaN    NaN

# %% [markdown]
# Well things didnt turned out.... as expected.

# %% [markdown]
# ![Screenshot from 2021-04-09 13-54-43.png](data:image/png;base64,...)

# %% [markdown]
# ### 📌Tracking the experiments.
#
#
# ***TOOLS:-***
# 1. **TensorBoard** :- A component of tensorflow library to help track modelling experiments.
# [TensorBoard](https://www.tensorflow.org/tensorboard)
#
# 2. **Weights and Biases** :- A tool for tracking all kinds of machine learning experiments(Plugs straight into TensorBoard).[Weights and Biases](https://wandb.ai/site)
