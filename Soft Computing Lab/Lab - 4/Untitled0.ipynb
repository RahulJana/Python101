# %%
'''
This code is for finding levestian distance for string matching 
uses packages like fuzzywuzzy and python-Levenshtein
Used to find the string that matches maximum with target string, something like finding closest string
    If the input string and target string are not same 100%, we can't do normal string comparison. Those 2 strings will never be same even if 1 letter/character is different
    So in this, we find the closest possible string
'''

# %%
pip install fuzzywuzzy

# %%
pip install python-Levenshtein
# Out:
# ...
#      |████████████████████████████████| 51kB 3.6MB/s
# ...
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144792 sha256=d76b34d3ea57b17a44359c46243eb9323b755cdb2b34391fa6b318ded47bf38c
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# ...

# %%
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process

# %%
''' Find target ration by comparison of the 2 strings '''

s1 = "I love GeeksforGeeks"
s2 = "I am loving GeeksforGeeks"
print ("FuzzyWuzzy Ratio: ", fuzz.ratio(s1, s2) )
print ("FuzzyWuzzy PartialRatio: ", fuzz.partial_ratio(s1, s2) )
print ("FuzzyWuzzy TokenSortRatio: ", fuzz.token_sort_ratio(s1, s2) )
print ("FuzzyWuzzy TokenSetRatio: ", fuzz.token_set_ratio(s1, s2) )
print ("FuzzyWuzzy WRatio: ", fuzz.WRatio(s1, s2),'\n\n')
# Out:
# FuzzyWuzzy Ratio:  84
# FuzzyWuzzy PartialRatio:  85
# FuzzyWuzzy TokenSortRatio:  84
# FuzzyWuzzy TokenSetRatio:  86
# FuzzyWuzzy WRatio:  84

# %%
''' 
For finding closest string
checks partial ratios to get the closest string to the main string
'''

query = 'geeks for geeks'                                      # Target string, need to find closest strings to this
choices = ['geek for geek', 'geek geek', 'g. for geeks']       # List of available strings, compare and get closest string
print ("List of ratios: ")
print (process.extract(query, choices), '\n')                  # process.extract method gives the partial ratio for all comparison strings 
print ("Best among the above list: ",process.extractOne(query, choices) )       # process.extractOne method gives the highest matching string
# Out:
# List of ratios:
# [('g. for geeks', 95), ('geek for geek', 93), ('geek geek', 86)]
#
# Best among the above list:  ('g. for geeks', 95)
