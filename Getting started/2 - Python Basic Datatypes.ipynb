# %%
num_of_students = 100

# %%
# ctrl+space -> auto complete
type(num_of_students)
# Out:
# int

# %%
type?

# %%
def sum_of_square(stop_value):
    """ But this line is shown; only is it is placed under the <<def fn()>> statement"""
    sum_ = 0
    # This line is not shown when we use help(sum_of_square)
    for i in range(stop_value):
        sum_ += i**2
        """ This line is not shown"""
    return sum_

# %%
SOS_5 = sum_of_square(5)

# %%
print(SOS_5)
# Out:
# 30

# %%
help(sum_of_square)
# Out:
# Help on function sum_of_square in module __main__:
#
# sum_of_square(stop_value)
#     But this line is shown; only is it is placed under the <<def fn()>> statement

# %%
sum_of_square?

# %%
a = list(range(5))
a
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# # Lambda Functions:
# - the anonymous functions
#
# func_name = lambda param1, param2: param1 </any operation/> param2

# %%
random_func = lambda param1, param2: param1 + param2

# %%
random_func(2,3)
# Out:
# 5

# %% [markdown]
# func_name = lambda var: </var operation/>, param_s

# %%
# Lambda functions:
b = lambda x: x**2, a

# %%
b
# Out:
# (<function __main__.<lambda>>, [0, 1, 2, 3, 4])

# %%
type(b)
# Out:
# tuple

# %%
b_ = list((lambda x: x**2, a))
b_
# Out:
# [<function __main__.<lambda>>, [0, 1, 2, 3, 4]]

# %% [markdown]
# #map

# %%
c = map(lambda x: x**2, a)

# %%
c

# %%
type(c)
# Out:
# map

# %%
map?

# %%
d = list(map(lambda x: x**2, a))

# %%
d
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# #filter

# %%
filter_func = filter(lambda x: x%2 == 0, d)
print(filter_func)
print(type(filter_func))
# Out:
# ...
# <class 'filter'>

# %%
filter_list = list(filter(lambda x: x%2 == 0, d))
filter_list
# Out:
# [0, 4, 16]

# %% [markdown]
# # touples

# %%
item_tup = (1,"Yo", 2.2)
item_tup
# Out:
# (1, 'Yo', 2.2)

# %%
# immutibility in a touple 
# item_tup[2] = "Change"
'''
---------------------------------------------------------------------------

TypeError                                 Traceback (most recent call last)

<ipython-input-82-ca286f871bd6> in <module>()
      1 # immutibility in a touple
----> 2 item_tup[2] = "Change"

TypeError: 'tuple' object does not support item assignment

'''
# Out:
# '\n---------------------------------------------------------------------------\n\nTypeError                                 Traceback (most recent call last)\n\n<ipython-input-82-ca286f871bd6> in <module>()\n      1 # immutibility in a touple\n----> 2 item_tup[2] = "Change"\n\nTypeError: \'tuple\' object does not support item assignment\n\n'

# %% [markdown]
# **If tpuple sucks.... why use it ??**

# %%
import time

# %%
time.time?

# %%
tic = time.time()
# put the executable code
toc = time.time()

# %%
print("time taken: ", toc- tic)
# Out:
# time taken:  3.886222839355469e-05

# %%
my_list = list(range(100000000))
tic = time.time()
my_list_squared = map(lambda i: i**2, my_list)
toc = time.time()
print("Elapsed time:", toc - tic)
# Out:
# Elapsed time: 8.845329284667969e-05

# %%
my_tuple = tuple(range(100000000))
tic = time.time()
my_tuple_squared = map(lambda i: i**2, my_tuple)
toc = time.time()
print("Elapsed time:", toc - tic)
# Out:
# Elapsed time: 8.20159912109375e-05

# %% [markdown]
# As we can see tuple takes less time.

# %% [markdown]
# # Sets

# %%
 a_list_q = list(range(5))
 a_list_q
# Out:
# [0, 1, 2, 3, 4]

# %%
my_set = set(a_list_q)
my_set
# Out:
# {0, 1, 2, 3, 4}

# %%
a_list_q.append(2)
print(a_list_q)
# Out:
# [0, 1, 2, 3, 4, 2]

# %%
my_set = set(a_list_q)
my_set
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# Set contains only unique elements

# %%
# adding elements to the set
my_set.add(6)
my_set
# Out:
# {0, 1, 2, 3, 4, 6}

# %% [markdown]
# Speed Comparison

# %%
# list
my_list = list(range(10000000))
tic = time.time()

print(123489 in my_list)
print(964454 in my_list)
print(654116684 in my_list)

toc = time.time()
print("Elapsed time:", toc - tic)
# Out:
# True
# True
# False
# Elapsed time: 0.1222226619720459

# %%
# Set
my_set = set(range(10000000))
tic = time.time()

print(123489 in my_set)
print(964454 in my_set)
print(654116684 in my_set)

toc = time.time()
print("Elapsed time:", toc - tic)
# Out:
# True
# True
# False
# Elapsed time: 0.00031185150146484375

# %% [markdown]
# Time taken is very low

# %% [markdown]
# # Dictionary

# %% [markdown]
# #Python Packages

# %%
# Writing our own factorial function
x = 1000
y = 1
tic = time.time()
for i in range(1, x+1):
    y *= i
print("fact", x, "is:", y)
toc = time.time()
print(toc-tic)
# Out:
# fact 1000 is: ...
# 0.0006365776062011719

# %%
import math
tic = time.time()
print (math.factorial(x))
toc = time.time()
print(toc-tic)
# Out:
# ...
# 0.0004169940948486328

# %% [markdown]
# As math library is more optimized it takes less time.

# %% [markdown]
# # Writing our own python module

# %%
# !echo "def hello(x):" > my_first_module.py
# !echo "    print('I am living in a different python file')" >> my_first_module.py

# %%
import my_first_module
my_first_module.hello(3)
# Out:
# I am living in a different python file
# 27
# This file can be used as a full fleged python file. #LOL
# HAHA
