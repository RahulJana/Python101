# %% [markdown]
# Since the code is executing on the google servers(unix based) so we can execute shell cmds in the shells
#
# **:~$ "!" "Standard cmds"**

# %%
# !ls
# Out:
# sample_data

# %%
# Cpu info
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0x1
# cpu MHz		: 2000.160
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# Memory info
# !cat /proc/meminfo
# Out:
# MemTotal:       13333596 kB
# MemFree:        10900296 kB
# MemAvailable:   12540088 kB
# Buffers:           74528 kB
# Cached:          1715064 kB
# SwapCached:            0 kB
# Active:           592688 kB
# Inactive:        1583516 kB
# Active(anon):     355036 kB
# Inactive(anon):      340 kB
# Active(file):     237652 kB
# Inactive(file):  1583176 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               628 kB
# Writeback:             0 kB
# AnonPages:        386592 kB
# Mapped:           206404 kB
# Shmem:               932 kB
# Slab:             157812 kB
# SReclaimable:     119572 kB
# SUnreclaim:        38240 kB
# KernelStack:        3812 kB
# PageTables:         5136 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6666796 kB
# Committed_AS:    2628508 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %% [markdown]
# This is a test cell .... The LaTeX format:-
# $LaTeX$

# %%
# !ls -l
# Out:
# total 43016
# drwxr-xr-x 1 root root     4096 Dec 21 17:29 sample_data
# -rw-r--r-- 1 root root 44040192 Dec 24 14:53 test.csv
