# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b96951c-9bd8-41c1-98b7-46acde47b66a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b96951c-9bd8-41c1-98b7-46acde47b66a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car.jpg to car.jpg
# Saving image.png to image.png

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

img = cv2.imread('image.png')

# find frequency of pixels in range 0-255
histogram = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histogram)
plt.show()

# %%
# alternative way to find histogram of an image
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("image.png")
layer = img.copy()
for i in range(4):
     plt.subplot(2, 2, i + 1)
# using pyrDown() function
# pyrDown: Higher Resolution to Lower Resolution
layer = cv2.pyrDown(layer)

plt.imshow(layer)
cv2_imshow(layer)
# Out:
# <PIL.Image.Image image mode=RGB size=703x527 at 0x7F8FC155C860>

# %% [markdown]
# # Image Translation

# %%
import numpy as np
# Store height and width of the image
height , width = img.shape[:2]
quater_height , quater_width = height/4 , width / 4
T = np.float32([[1,0,quater_width],[0,1,quater_height]])
img_translation = cv2.warpAffine(img,T,(width,height))

cv2_imshow(img)
cv2_imshow(img_translation)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
layer = img.copy()
for i in range(4):
  plt.subplot(2,2,i + 1)
  layer = cv2.pyrDown(layer)
  plt.imshow(layer)

# %%
layer = img.copy()
for i in range(4):
  plt.subplot(2,2,i + 1)
  layer = cv2.pyrUp(layer)
  plt.imshow(layer)

# %% [markdown]
# # WE have to do horizontal shift and vertical shift and Histogram different channels.
