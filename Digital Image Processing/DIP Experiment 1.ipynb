# %% [markdown]
# #Method 1
# #Using Pillow (PIL) Modile

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0dcfa24c-e20e-4504-b485-d31e9c3ef3f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dcfa24c-e20e-4504-b485-d31e9c3ef3f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.png to image.png

# %%
from PIL import Image
img = Image.open('image.png')
img.show()

# %% [markdown]
# #Method 1.2
# #Using Pillow (PIL) with matplotlib module

# %%
from PIL import Image
import matplotlib.pyplot as plt
img = plt.imread('image.png')
plt.imshow(img)

# %% [markdown]
# #Method 2
# #Using Matplotlib module

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('image.png')
plt.imshow(img)

# %% [markdown]
# #Method 3
# #Using imageio with matplotlib module

# %%
import imageio
import matplotlib.pyplot as plt
img = imageio.imread('image.png')
plt.imshow(img)

# %% [markdown]
# #Method 4
# #Using OpenCV module

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2 as cv
img = cv.imread('image.png',1)
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Method 5
# #Using OpenCV with Matplotlib module

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('image.png',-1)
plt.imshow(img)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('image.png',0)
RGBimg = cv.cvtColor(img, cv.COLOR_BAYER_BG2BGR)
plt.imshow(img)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('image.png',0)
RGBimg = cv.cvtColor(img, cv.COLOR_BAYER_BG2BGR)
plt.imshow(RGBimg)
