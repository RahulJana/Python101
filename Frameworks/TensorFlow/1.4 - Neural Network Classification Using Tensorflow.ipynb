# %% [markdown]
# ## Basic Intuition of a Classification Model/Problem:
# Let's say we are doing a Image classification,
# * ***Binary Classifiaction:*** Image classification() cat vs Dog
#
# * ***Multi Class Classification:*** (More than two class) Cat Vs Dog Vs Bird Image, Flower Classication is example of Multi-Class Classification, Each Image contains only one class.
# > Email Classifier is an example of Multi Class Classification. {Office, SHopping, Spam}
# * ***Multi Label CLassification:*** Image Tagging(An Image contains both Cat and Dog, and we have to add two labels or tags to the image then it is a multi label Classification.)
# > Movie review tagging could be an example of Multi Label Classification
#
# * > **Some common parameters for Input Image:**
# 1. **Batch_size:** 32(According to Processors architecture batch size is determined, 32 is satndard and Default batch size of the Tensorflow.) or None(None Refers to Batch size is not set, It could be a arbirary number). *Ammount of Images the system Processor(CPU or GPU) can look at.*
#
# 2. **Width:** Width of an Image.
# 3. **Height:** Height of an Image.
# 4. **Color Channel:** Generally 3.
#
# * > ***Output Shape:***
# * > > let we have 3-classes at multi Class: 1. Cat; 2. Dog; 3. Bird.  Then the output shape is [3] ----> Example [0.04, 0.9, 0.06]; The Image is Dog.

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# External Resources:
# https://karpathy.github.io/2019/04/25/recipe/

# %% [markdown]
# ## Architecture(typical) of a Classification model:
#
#
# # Random seed
# tf.random.set_seed(69)
#
#
# # Create a model
# multiclass_model_1 = tf.keras.Sequential([
#                              keras.Input(shape = (224, 224, 3)),
#                              keras.layers.Dense(100, activation = "relu"),
#                              keras.layers.Dense(3, activation = "softmax")
# ])
#
#
# # Compile Model
# multiclass_model_1.compile(loss = tf.keras.losses.CategoricalCrossentropy(),
#               optimizer = tf.keras.optimizers.Adam(),
#               metrics = ["accuracy"])
#
#
# # Fit the model
# multiclass_model_history = multiclass_model_1.fit(X_train, y_train, epochs = 10)
#
#
# # Evaluate model
# multiclass_model.evaluate(X_test, y_test)

# %% [markdown]
# ## Source code

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.datasets import make_circles

# %%
# Creating a 1000 exapmles 
n_examples = 5000

# Create Circles
X, y = make_circles(n_examples)

# Create Circles
X, y = make_circles(n_examples, noise = 0.03, random_state= 69)

# %%
X, X.shape
# Out:
# (array([[-0.57262626, -0.60035483],
#         [ 0.66485204,  0.33752938],
#         [ 0.21566936, -0.8093595 ],
#         ...,
#         [-0.59836965, -0.76612396],
#         [ 0.80405907,  0.38831004],
#         [-0.58175543, -0.55960826]]), (5000, 2))

# %%
y, y.shape
# Out:
# (array([1, 1, 1, ..., 0, 1, 1]), (5000,))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
circles = pd.DataFrame({"X0" : X[:, 0],
                        "X1" : X[:, 1],
                        "label" : y})
circles
# Out:
#             X0        X1  label
# 0    -0.572626 -0.600355      1
# 1     0.664852  0.337529      1
# 2     0.215669 -0.809360      1
# 3     0.812002  0.081994      1
# 4    -0.826343 -0.533784      0
# ...        ...       ...    ...
# 4995 -0.802943  0.225051      1
# 4996  0.442019  0.891607      0
# 4997 -0.598370 -0.766124      0
# 4998  0.804059  0.388310      1
# 4999 -0.581755 -0.559608      1
#
# [5000 rows x 3 columns]

# %%
# Visualization
plt.figure(figsize=(10,10))
plt.scatter(X[:, 0], X[:, 1], c = y, cmap = plt.cm.RdYlBu)

# %% [markdown]
# ##### [Tensorflow Play Ground🔥🔥🔥](https://playground.tensorflow.org/#activation=sigmoid&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.01&regularizationRate=0&noise=0&networkShape=&seed=0.30688&showTestData=false&discretize=false&percTrainData=50&x=false&y=false&xTimesY=true&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)

# %% [markdown]
# ## Back To code

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 69)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4000, 2), (1000, 2), (4000,), (1000,))

# %% [markdown]
# ## Creating a model

# %%
# Setting the random seed
tf.random.set_seed(69)


# Creating a model
circle_model_1 = keras.Sequential([
                                   # keras.layers.Input(2),
                                   keras.layers.Dense(10, activation = "relu"),
                                   keras.layers.Dense(5, activation = "relu"),
                                   keras.layers.Dense(1, activation = "sigmoid" )
])


# compiling a model
circle_model_1.compile(loss = keras.losses.binary_crossentropy,
                       optimizer = keras.optimizers.Adam(),
                       metrics = [keras.metrics.Accuracy()])

# Fitting the model
history_1 = circle_model_1.fit(X_train, y_train, epochs = 300, verbose = 1)
# Out:
# Epoch 1/300
# 125/125 [==============================] - 1s 1ms/step - loss: 0.6961 - accuracy: 0.0000e+00
# Epoch 2/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6902 - accuracy: 0.0000e+00
# Epoch 3/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6859 - accuracy: 0.0000e+00
# Epoch 4/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6817 - accuracy: 0.0000e+00
# Epoch 5/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6728 - accuracy: 0.0000e+00
# Epoch 6/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6609 - accuracy: 0.0000e+00
# Epoch 7/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.6304 - accuracy: 0.0000e+00
# Epoch 8/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5865 - accuracy: 0.0000e+00
# Epoch 9/300
# 125/125 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.0000e+00
# Epoch 10/300
# ...

# %%
circle_model_evaluate = circle_model_1.evaluate(X_test, y_test)
# Out:
# 32/32 [==============================] - 0s 982us/step - loss: 0.0063 - accuracy: 0.1660

# %% [markdown]
# ## Model 2: With larger number of layers and neurons

# %%
tf.random.set_seed(69)
circle_model_2 = keras.Sequential([
                                   keras.layers.Dense(2),
                                   keras.layers.Dense(16, activation= "relu"),
                                   keras.layers.Dense(128, activation= "relu"),
                                   keras.layers.Dense(265, activation= "relu"),
                                   keras.layers.Dense(32, activation= "relu"),
                                   keras.layers.Dense(1, activation= "sigmoid")
])
circle_model_2.compile(loss = keras.losses.binary_crossentropy,
                       optimizer = keras.optimizers.SGD(),
                       metrics = ["Accuracy"])
circle_model_2.fit(X_train, y_train, epochs = 300, verbose= 0)

# %%
circle_model_2.evaluate(X_test, y_test)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 0.0000e+00
# [0.007067881058901548, 0.0]

# %% [markdown]
# Since nothing is doing any good lets do some visualization

# %% [markdown]
# ## Creating a model for creating a visualization of decision boundary:
# * ***Recipe:***
# 1. https://cs231n.github.io/neural-networks-case-study/
# 2. https://github.com/madewithml/guides
# > * Take a trained model, features(X) and labels(y)
# > * Create meshgrid of different X values
# > * Make predictions accross a mesh grid [Link of Mesh Grid](https://www.geeksforgeeks.org/numpy-meshgrid-function/)
# > * Plot the predictions as well as a line b/w zones

# %%
# Creating function for ploting a decision boundary
def plot_decission_boundary(model, X, y):
    """
    Plots the decision boundary created by model predictions
    this fn is borrowed from:---------->
    https://cs231n.github.io/neural-networks-case-study/ and 
    https://github.com/madewithml/guides
    """

    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))
    
    # Create X value (We will be making predictions on these)
    x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D-arrays together

    # Make Predictions
    y_pred = model.predict(x_in)

    # Check for multi-class
    if len(y_pred[0])> 1:
        print("Multiclass Classification.")
        # Since this a multi-class classification
        y_pred = np.round(y_pred).reshape(xx.shape)
    else:
        print("Binary Classification,")
        y_pred = np.round(y_pred).reshape(xx.shape)
    
    # Plot Decision boundary
    plt.figure(figsize=(7,7))
    plt.contourf(xx, yy, y_pred, cmap = plt.cm.RdYlBu, alpha = 0.7)
    plt.scatter(X[:, 0], X[:, 1], c = y, s = 40, cmap = plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
'''x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

x_min, x_max, y_min, y_max'''


# Output:
'''
(-1.1550061421731352,
 1.1713485433922906,
 -1.1814217354567302,
 1.1667778330139513)

'''
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# =================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
'''
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))

xx, yy

'''

# output:
'''
(array([[-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854],
        [-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854],
        [-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854],
        ...,
        [-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854],
        [-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854],
        [-1.15500614, -1.13150761, -1.10800908, ...,  1.12435148,
          1.14785001,  1.17134854]]),
 array([[-1.18142174, -1.18142174, -1.18142174, ..., -1.18142174,
         -1.18142174, -1.18142174],
        [-1.15770255, -1.15770255, -1.15770255, ..., -1.15770255,
         -1.15770255, -1.15770255],
        [-1.13398336, -1.13398336, -1.13398336, ..., -1.13398336,
         -1.13398336, -1.13398336],
        ...,
        [ 1.11933946,  1.11933946,  1.11933946, ...,  1.11933946,
          1.11933946,  1.11933946],
        [ 1.14305865,  1.14305865,  1.14305865, ...,  1.14305865,
          1.14305865,  1.14305865],
        [ 1.16677783,  1.16677783,  1.16677783, ...,  1.16677783,
          1.16677783,  1.16677783]]))

'''



'''
xx.shape, yy.shape

'''
# Output: ((100, 100), (100, 100))
# Out:
# '\nxx.shape, yy.shape\n\n'

# %%
plot_decission_boundary(model = circle_model_1, X = X, y = y)
# Out:
# Binary Classification,

# %%
plot_decission_boundary(model = circle_model_1, X = X_train, y = y_train)
# Out:
# Binary Classification,

# %%
plot_decission_boundary(model = circle_model_2, X = X, y = y)
# Out:
# Binary Classification,

# %%
plot_decission_boundary(model = circle_model_2, X = X_train, y = y_train)
# Out:
# Binary Classification,

# %%
plot_decission_boundary(model = circle_model_1, X = X_test, y = y_test)
# Out:
# Binary Classification,

# %%
plot_decission_boundary(model = circle_model_2, X = X_test, y = y_test)
# Out:
# Binary Classification,
