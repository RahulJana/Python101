# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('colour.jpg', cv2.IMREAD_COLOR)
plt.figure(figsize=(20,8))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7864/2950208466.py in <module>
#       4 img = cv2.imread('colour.jpg', cv2.IMREAD_COLOR)
#       5 plt.figure(figsize=(20,8))
# ----> 6 plt.imshow(img)
#
# c:\Users\irahu\.conda\envs\tf_2.4\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# c:\Users\irahu\.conda\envs\tf_2.4\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1470     def inner(ax, *args, data=None, **kwargs):
#    1471         if data is None:
# -> 1472             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1473
#    1474         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\irahu\.conda\envs\tf_2.4\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5663                               **kwargs)
#    5664
# -> 5665         im.set_data(X)
#    5666         im.set_alpha(alpha)
#    5667         if im.get_clip_path() is None:
#
# c:\Users\irahu\.conda\envs\tf_2.4\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     699         if (self._A.dtype != np.uint8 and
#     700                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 701             raise TypeError("Image data of dtype {} cannot be converted to "
#     702                             "float".format(self._A.dtype))
#     703
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Importing required modules
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Defining and reading an Image usinig opencv module
img = cv2.imread('colour.jpg', cv2.IMREAD_COLOR)
# Convert GBR colour mode to RGB colour mode
RGBimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Ploting and Displaying the image
plt.figure(figsize=(20,8))
plt.imshow(RGBimg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7864/3810821470.py in <module>
#       6 img = cv2.imread('colour.jpg', cv2.IMREAD_COLOR)
#       7 # Convert GBR colour mode to RGB colour mode
# ----> 8 RGBimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       9 # Ploting and Displaying the image
#      10 plt.figure(figsize=(20,8))
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-q3d_8t8e\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# # RGB to HSV

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('colour.jpg',cv2.IMREAD_COLOR)
RGBimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
HSVimg = cv2.cvtColor(RGBimg,cv2.COLOR_RGB2HSV)
plt.figure(figsize=(10,10))
plt.imshow(HSVimg)

# %% [markdown]
# ## Detect Specific Colour

# %%
# Importing required modules
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Defining and reading an Image usinig opencv module
img = cv2.imread('colour.jpg',cv2.IMREAD_COLOR)
# Convert GBR colour mode to RGB colour mode
RGBimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Convert RGB colour mode to HSV colour mode
HSVimg = cv2.cvtColor(RGBimg,cv2.COLOR_RGB2HSV)
lower = np.array([25,150,50])
upper = np.array([35,255,255])
# To detetic a specific color eg: yellow
mask = cv2.inRange(HSVimg,lower,upper)
plt.figure(figsize=(20,8))
plt.imshow(res)

# %% [markdown]
# ## To show a particular color and blacken out the other colors

# %%
# Importing required modules
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Defining and reading an Image usinig opencv module
img = cv2.imread('image.png',cv2.IMREAD_COLOR)
# Convert GBR colour mode to RGB colour mode
RGBimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Convert RGB colour mode to HSV colour mode
HSVimg = cv2.cvtColor(RGBimg,cv2.COLOR_RGB2HSV)
lower = np.array([25,150,50])
upper = np.array([35,255,255])
# To detetic a specific color eg: yellow
mask = cv2.inRange(HSVimg,lower,upper)
# To blacken out the other colors
res=cv2.bitwise_and(RGBimg, RGBimg, mask=mask)
plt.figure(figsize=(20,8))
plt.imshow(res)

# %% [markdown]
# # To Detect RED Colour

# %%
# Importing required modules
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Defining and reading an Image usinig opencv module
img = cv2.imread('image.png',cv2.IMREAD_COLOR)
# Convert GBR colour mode to RGB colour mode
RGBimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#Convert RGB colour mode to HSV colour mode
HSVimg = cv2.cvtColor(RGBimg,cv2.COLOR_RGB2HSV)
lower = np.array([0,150,50])
upper = np.array([10,255,255])
# To detetic a specific color eg: RED
mask = cv2.inRange(HSVimg,lower,upper)
plt.figure(figsize=(20,8))
plt.imshow(res)

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
img = cv2.imread('image.png',cv2.IMREAD_COLOR)
cv2.line(img,(355,0),(250,350),(0,240,0),8)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import numpy as np
import cv2
img = cv2.imread('image.png',cv2.IMREAD_COLOR)
cv2.line(img,(355,0),(250,350),(0,240,0),8)
cv2.rectangle(img,(100,0),(400,300),(0,240,255),8)
cv2.circle(img,(100,60),35,(0,220,110),8)
pts = np.array([[10,5],[20,30],[70,20]],np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img,[pts],True,(125,0,0),3)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'WELCOME',(20,150),font,2,(125,10,110),2,cv2.LINE_AA)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# Output hidden; open in https://colab.research.google.com to view.
