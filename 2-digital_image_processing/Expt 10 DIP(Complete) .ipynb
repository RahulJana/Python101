# %% [markdown]
# # Morhological Transformation
# Morphological transformations are some simple operations based on the image shape. It is normally performed
# on binary images

# %% [markdown]
# # Erosion

# %%
from google.colab import files
Uploaded = files.upload()
# Out:
#      <input type="file" id="files-194e8432-3149-467d-aa8e-1c01f57ade32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-194e8432-3149-467d-aa8e-1c01f57ade32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving download.jpg to download (1).jpg

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)
cv2_imshow(img)
cv2_imshow(erosion)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Dilation

# %%
import cv2 as cv
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
dilation = cv.dilate(img,kernel,iterations = 1)
cv2_imshow(img)
cv2_imshow(dilation)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Opening

# %%
import cv2 as cv
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
cv2_imshow(img)
cv2_imshow(opening)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Closing

# %%
import cv2 as cv
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
cv2_imshow(img)
cv2_imshow(closing)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Morphological Gradient

# %%
import cv2 as cv
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
cv2_imshow(img)
cv2_imshow(gradient)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Top Hat

# %%
import cv2 as cv
import numpy as np
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
cv2_imshow(img)
cv2_imshow(tophat)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Black Hat

# %%
img = cv.imread('download.jpg')
kernel = np.ones((5,5),np.uint8)
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
cv2_imshow(img)
cv2_imshow(blackhat)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Alternate method

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max Value of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
titles= ['image','mask']
images=[img,mask]
for i in range(2):
    plt.subplot(1, 2, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
#kernal = np.ones((2,2), np.uint8)
kernal = np.ones((5,5), np.uint8)
#dilation = cv2.dilate(mask, kernal)
dilation = cv2.dilate(mask, kernal, iterations=2)
titles= ['image','mask','dilation']
images=[img,mask,dilation]
for i in range(3):
     plt.subplot(1, 3, i+1), plt.imshow(images[i], 'gray')
     plt.title(titles[i])
     plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
#kernal = np.ones((5,5), np.uint8)
erosion = cv2.erode(mask, kernal)
#erosion = cv2.erode(mask, kernal, iterations=1)
titles= ['image','mask','erosion']
images=[img,mask,erosion]
for i in range(3):
     plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
     plt.title(titles[i])
     plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
#kernal = np.ones((5,5), np.uint8)
# opening= erosion+ dilation
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)
titles= ['image','mask','opening']
images=[img,mask,opening]
for i in range(3):
     plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
     plt.title(titles[i])
     plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
#kernal = np.ones((5,5), np.uint8)
#closing= dilation+erosion
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)
titles= ['image','mask','closing']
images=[img,mask,closing]
for i in range(3):
    plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((2,2), np.uint8)
#kernal = np.ones((5,5), np.uint8)
#morphology gradient
mg = cv2.morphologyEx(mask, cv2.MORPH_GRADIENT, kernal)
titles= ['image','mask','mg']
images=[img,mask,mg]
for i in range(3):
    plt.subplot(1,3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
#importing the libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
# reading image in graysacle mode
img = cv2.imread('download.jpg', cv2.IMREAD_GRAYSCALE)
# applying mask, img, value of threshnold, max alue of threshold, type of threshold
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)
kernal = np.ones((5,5), np.uint8)
dilation = cv2.dilate(mask, kernal, iterations=2)
erosion = cv2.erode(mask, kernal, iterations=1)
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)
mg = cv2.morphologyEx(mask, cv2.MORPH_GRADIENT, kernal)
th = cv2.morphologyEx(mask, cv2.MORPH_TOPHAT, kernal)
titles = ['image', 'mask', 'dilation', 'erosion', 'opening', 'closing', 'mg', 'th']
images = [img, mask, dilation, erosion, opening, closing, mg, th]
for i in range(8):
    plt.subplot(2, 4, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
