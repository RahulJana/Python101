# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
'''
Acts as the connector b/w colab and the drive.
This snippet needs to be run only once.
'''
# Part 1
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
# Part 2
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Sample file.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 10Q9_0m1JC3KETG4oWMGWfUwpI5E9gQAC

# %% [markdown]
# ### **Disclaimer:**
# This code snippet actually uploads the file to the google colab. Part 1 & 2 is the authentication part, which needs to be done only once.

# %%
uploaded = drive.CreateFile({'title': 'Sample_file made by me.txt'})
uploaded.SetContentString('I am uploading something to my google drive. eg.- o/p, data etc.')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1A9oRO8tIDbdk2ff5N4OZ6F56xVAedJb1

# %%
# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.txt' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title Sample_file made by me.txt, id 1A9oRO8tIDbdk2ff5N4OZ6F56xVAedJb1
# title Sample file.txt, id 10Q9_0m1JC3KETG4oWMGWfUwpI5E9gQAC
